# %%
import DataAccess

feature_ids = [8153461, 8153027, 18210860]
start_date = "202202110000"
end_date   = "202202120000"
fcst_cycle = [0]
lead_time  = [1]

df = DataAccess.data_access_streamflow(start_date, end_date, feature_ids, fcst_cycle, lead_time)
# Out:
# no ensemble members available for the given runinput therefore, meminput set to None

# %%
df
# Out:
#                                     8153461  8153027    18210860
# time
# [2022-02-11T01:00:00.000000000]  249.339994     5.30  437.109990
# [2022-02-12T01:00:00.000000000]  249.759994     6.85  385.729991

# %%
cat_ids = ['cat-3299613', 'cat-3299526']
fcst_cycle = [0,8]
lead_time = [1,18]

ds = DataAccess.data_access_forcing(start_date, end_date, cat_ids, "/Users/awistudent/.ngiab/hydrofabric/v2.2/conus_nextgen.gpkg", fcst_cycle, lead_time)
# Out:
# Opening hydrofabric and subsetting the given catchments
# no ensemble members available for the given runinput therefore, meminput set to None
# /Users/awistudent/Documents/Sonam/Contribute_Forecast/data_access_example/DataAccess.py:73: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'reference_time' ('reference_time',) The recommendation is to set join explicitly for this case.
#   gridded_data = xr.open_mfdataset(url_list, combine= 'nested',concat_dim='time', engine = 'kerchunk', storage_options = {})
# ...

# %%
ds
# Out:
# <xarray.Dataset> Size: 664B
# Dimensions:   (catchment-id: 2, time: 8)
# Dimensions without coordinates: catchment-id, time
# Data variables:
#     RAINRATE  (catchment-id, time) float32 64B ...
#     LWDOWN    (catchment-id, time) float32 64B ...
#     Q2D       (catchment-id, time) float32 64B ...
#     V2D       (catchment-id, time) float32 64B ...
#     SWDOWN    (catchment-id, time) float32 64B ...
#     PSFC      (catchment-id, time) float32 64B ...
#     T2D       (catchment-id, time) float32 64B ...
#     U2D       (catchment-id, time) float32 64B ...
#     ids       (catchment-id) <U11 88B ...
#     Time      (catchment-id, time) int32 64B ...
